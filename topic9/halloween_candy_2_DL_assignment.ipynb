# %% [markdown]
# <a href="https://colab.research.google.com/github/alouwyck/vives-intro-to-ai/blob/main/topic9/halloween_candy_2_DL_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." align="right" /><br>
#
#
# **INTRODUCTION TO ARTIFICIAL INTELLIGENCE**<br>
# VIVES BUSINESS ACADEMY<br>
# Academic Year 2023-2024<br>
# Andy Louwyck
#
# ---
#
#
#
# ---

# %% [markdown]
# # **HALLOWEEN CANDY: PART II**

# %% [markdown]
# ## Intro

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What is the most popular Halloween candy? That was the question asked by [Walt Hickey](https://walthickey.com/2017/10/18/whats-the-best-halloween-candy/)! Data was collected by creating a website where participants were shown presenting two fun-sized candies and asked to click on the one they would prefer to receive. In total, more than 269 thousand votes were collected from 8,371 different IP addresses. An analysis of the data was performed by [fivethirtyeight](https://fivethirtyeight.com/videos/the-ultimate-halloween-candy-power-ranking/).

# %% [markdown]
# ## Instructions

# %% [markdown]
# - Download the Halloween Candy dataset from [Kaggle](https://en.wikipedia.org/wiki/Kaggle): https://www.kaggle.com/datasets/fivethirtyeight/the-ultimate-halloween-candy-power-ranking
# - The data are stored in file `'candy-data.csv'`. Read the file using Pandas function `read_csv` and explore the data. How many samples does the dataset contain? What are the features? Are these features categorical or quantitative? Do you have to scale some of these features?
# - Split the dataset in a training set that consists of 75 samples. Use the other samples as test set. There is a function `train_test_split` in Scikit-Learn that may be handy here...
# - Use the training set to build and train an artificial neural network that predicts the *winpercent* of a given candy. Apply Keras' `Sequential` class and use `Dense` layers. Set the `validation_split` to 20%.
# - Plot the loss function against the epochs for both training and validation. Check after how many epochs overfitting starts to happen. Re-train the model using that number of epochs. You don't need to validate your model anymore.
# - Evaluate the performance of this final model on both the training and the test set by applying the following metrics:
#   - mean absolute error (MAE)
#   - root mean squared error (RMSE)
#   - coefficient of determination (R²)
# - Create a scatter graph that plots the predicted win percentages against the true percentages for both the training and the test set. Use blue dots for the first and red dots for the latter. Add axes labels and a legend to the graph.
# - Discuss your results!

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Import statements

# %% [markdown]
# ### The dataset

# %% [markdown]
# ### The Neural Network

# %% [markdown]
# ### Conclusion
